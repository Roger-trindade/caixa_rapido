# %% [markdown]
# <a href="https://colab.research.google.com/github/Roger-trindade/caixa_rapido/blob/main/Aprendizado_supervisionado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# dontpad.com/710DS-0308

# %%
import pandas as pd
import numpy as np

from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score

# %% [markdown]
# # Modelo ótimo

# %% [markdown]
# ## Carregamento dos dados

# %%
data = {
    'Marketing' : [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
    'Vendas' : [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
}
df = pd.DataFrame(data)
df
# Out:
#    Marketing  Vendas
# 0        100      50
# 1        200     100
# 2        300     150
# 3        400     200
# 4        500     250
# 5        600     300
# 6        700     350
# 7        800     400
# 8        900     450
# 9       1000     500

# %% [markdown]
# Espera-se que a função seja do tipo y = 0.5 * x

# %% [markdown]
# ## Separação X e Y

# %%
X = df[['Marketing']]
y = df['Vendas']

# %%
X
# Out:
#    Marketing
# 0        100
# 1        200
# 2        300
# 3        400
# 4        500
# 5        600
# 6        700
# 7        800
# 8        900
# 9       1000

# %%
y
# Out:
# 0     50
# 1    100
# 2    150
# 3    200
# 4    250
# 5    300
# 6    350
# 7    400
# 8    450
# 9    500
# Name: Vendas, dtype: int64

# %% [markdown]
# ## Separação treino e teste

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 93)

# %%
X_treino
# Out:
#    Marketing
# 6        700
# 7        800
# 9       1000
# 1        200
# 0        100
# 4        500
# 5        600

# %%
X_teste
# Out:
#    Marketing
# 2        300
# 8        900
# 3        400

# %% [markdown]
# ## Criar o modelo

# %%
modelo = LinearRegression()

# %%
modelo
# Out:
# LinearRegression()

# %%
modelo.fit(X_treino, y_treino)
# Out:
# LinearRegression()

# %%
modelo.coef_
# Out:
# array([0.5])

# %%
modelo.intercept_ # É o mesmo de -0.00000000000001 e é praticamente 0
# Out:
# -1.1368683772161603e-13

# %%
previsao = modelo.predict(X_teste)
previsao
# Out:
# array([150., 450., 200.])

# %%
X_teste
# Out:
#    Marketing
# 2        300
# 8        900
# 3        400

# %% [markdown]
# ## Calculando erro do modelo

# %%
mse = mean_squared_error(y_teste, previsao)
mse
# Out:
# 5.6545549686242126e-27

# %% [markdown]
# # Modelo não-ótimo

# %%
data = {
    'Marketing' : [110, 190, 310, 390, 510, 590, 710, 790, 910, 990],
    'Vendas' : [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
}
df = pd.DataFrame(data)
df
# Out:
#    Marketing  Vendas
# 0        110      50
# 1        190     100
# 2        310     150
# 3        390     200
# 4        510     250
# 5        590     300
# 6        710     350
# 7        790     400
# 8        910     450
# 9        990     500

# %% [markdown]
# ## Separaçao X e Y

# %%
X = df[['Marketing']]
y = df['Vendas']

# %%
X
# Out:
#    Marketing
# 0        110
# 1        190
# 2        310
# 3        390
# 4        510
# 5        590
# 6        710
# 7        790
# 8        910
# 9        990

# %%
y
# Out:
# 0     50
# 1    100
# 2    150
# 3    200
# 4    250
# 5    300
# 6    350
# 7    400
# 8    450
# 9    500
# Name: Vendas, dtype: int64

# %% [markdown]
# ## Separaçao treino e teste

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 93)

# %%
X_treino
# Out:
#    Marketing
# 6        710
# 7        790
# 9        990
# 1        190
# 0        110
# 4        510
# 5        590

# %%
X_teste
# Out:
#    Marketing
# 2        310
# 8        910
# 3        390

# %% [markdown]
# ## Criar modelo

# %%
modelo = LinearRegression()

# %%
modelo
# Out:
# LinearRegression()

# %%
modelo.fit(X_treino, y_treino)
# Out:
# LinearRegression()

# %%
modelo.coef_
# Out:
# array([0.50559136])

# %%
modelo.intercept_
# Out:
# -2.392911296436637

# %%
previsao = modelo.predict(X_teste)
previsao
# Out:
# array([154.3404094 , 457.69522365, 194.78771797])

# %%
X_teste
# Out:
#    Marketing
# 2        310
# 8        910
# 3        390

# %% [markdown]
# ## calculando erro do modelo

# %%
mse = mean_squared_error(y_teste, previsao)
mse
# Out:
# 35.074501612577905

# %% [markdown]
# # modelo - Classificador

# %% [markdown]
# ## Carregamento de dados

# %%
df = pd.DataFrame({
    'Idade' : [25, 35, 45, 20, 30, 50, 40, 55, 60, 70],
    'Renda' : [3000, 4000, 5000, 2000, 3500, 6000, 5500, 7000, 8000, 9000],
    'Compra' : [0,0,1,0,1,1,1,1,1,1]
})
df
# Out:
#    Idade  Renda  Compra
# 0     25   3000       0
# 1     35   4000       0
# 2     45   5000       1
# 3     20   2000       0
# 4     30   3500       1
# 5     50   6000       1
# 6     40   5500       1
# 7     55   7000       1
# 8     60   8000       1
# 9     70   9000       1

# %%
X = df[['Idade', 'Renda']]
y = df['Compra']

# %%
X
# Out:
#    Idade  Renda
# 0     25   3000
# 1     35   4000
# 2     45   5000
# 3     20   2000
# 4     30   3500
# 5     50   6000
# 6     40   5500
# 7     55   7000
# 8     60   8000
# 9     70   9000

# %% [markdown]
# ## Separaçao treino teste

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, test_size = 0.3, random_state = 93)

# %%
X_treino
# Out:
#    Idade  Renda
# 6     40   5500
# 7     55   7000
# 9     70   9000
# 1     35   4000
# 0     25   3000
# 4     30   3500
# 5     50   6000

# %% [markdown]
# ## Criando o modelo

# %%
modelo_logistico = LogisticRegression()
modelo_logistico
# Out:
# LogisticRegression()

# %%
modelo_logistico.fit(X_treino, y_treino)
# Out:
# LogisticRegression()

# %%
modelo_logistico.coef_
# Out:
# array([[-0.594672  ,  0.00515452]])

# %%
modelo_logistico.intercept_
# Out:
# array([-0.10056524])

# %%
previsao_logistica = modelo_logistico.predict(X_teste)
previsao_logistica
# Out:
# array([0, 1, 0])

# %%
X_teste
# Out:
#    Idade  Renda
# 2     45   5000
# 8     60   8000
# 3     20   2000

# %% [markdown]
# ## Calcula acurácia

# %%
acuracia = accuracy_score(y_teste, previsao_logistica)
acuracia
# Out:
# 0.6666666666666666

# %% [markdown]
# <a href="https://colab.research.google.com/github/Roger-trindade/caixa_rapido/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução a Data Science

# %%
# Importando a biblioteca pandas:
import pandas as pd

# %% [markdown]
# ## Criando Series

# %%
# Ex01.
uf = ['BA', 'MG', 'PE', 'SE', 'SC']
uf = pd.Series(uf, name='Sigla')
uf
# Out:
# 0    BA
# 1    MG
# 2    PE
# 3    SE
# 4    SC
# Name: Sigla, dtype: object

# %%
# Ex02.
estados = ['Bahia', 'Minas Gerais', 'Pernanbuco', 'Sergipe', 'Santa Catarina']
estados = pd.Series(estados, name='Estados')
estados
# Out:
# 0             Bahia
# 1      Minas Gerais
# 2        Pernanbuco
# 3           Sergipe
# 4    Santa Catarina
# Name: Estados, dtype: object

# %% [markdown]
# ## Criando Dataframes

# %% [markdown]
# ### Dicionários

# %%
# Criando Primeiro DataFrame
data = {
    'Regiões do Brasil': ['Sul', 'Sudeste', 'Centro-Oeste', 'Nordeste', 'Norte'],
    'População (Milhões)': [28, 79, 14, 46, 13]
}

regioes_df = pd.DataFrame(data)
regioes_df['Regiões do Brasil']
# Out:
# 0             Sul
# 1         Sudeste
# 2    Centro-Oeste
# 3        Nordeste
# 4           Norte
# Name: Regiões do Brasil, dtype: object

# %% [markdown]
# ### Series

# %%
# Criando Dataframe através de um dicionario com Series
data = {
    'UF': uf,
    'Estados': estados
}

estados_df = pd.DataFrame(data)

# %%
# Criando Dataframe através de Series
estados_df = pd.concat([estados, uf], axis='columns')
estados_df
# Out:
#           Estados Sigla
# 0           Bahia    BA
# 1    Minas Gerais    MG
# 2      Pernanbuco    PE
# 3         Sergipe    SE
# 4  Santa Catarina    SC

# %% [markdown]
# ### Lendo Arquivos

# %%
# Encoding
brasil_population = pd.read_csv('./brazil_population.csv')

# %% [markdown]
# ## Explorando Dados

# %%
# Trazendo os 5 Primeiros Registros
brasil_population.head()
# Out:
#    Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 0  2020   212559417             0.72        1509890           21200
# 1  2019   211049527             0.75        1580204           21200
# 2  2018   209469323             0.79        1635500           21200
# 3  2017   207833823             0.81        1670770           21200
# 4  2016   206163053             0.83        1691284           21200
#
#    Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  Urban Population  \
# 0        33.5            1.74               25         87.6         186217070
# 1        31.8            1.76               25         87.4         184407548
# 2        31.8            1.76               25         87.1         182546459
# 3        31.8            1.76               25         86.9         180633872
# 4        31.8            1.76               25         86.7         178669587
#
#    Country's Share of World Pop  World Population  Brazil Global Rank
# ...

# %%
# Trazendo os 5 Ultimos Registros
brasil_population.tail()
# Out:
#     Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 13  1975   107216205             2.42        2420588               0
# 14  1970    95113265             2.67        2347947               0
# 15  1965    83373530             2.93        2238861               0
# 16  1960    72179226             2.91        1929061               0
# 17  1955    62533919             2.99        1711838           59635
#
#     Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  \
# 13        19.5            4.63               13         61.0
# 14        18.6            5.34               11         56.0
# 15        18.3            5.97               10         51.1
# 16        18.6            6.06                9         46.2
# 17        18.9            6.10                7         41.1
#
#     Urban Population  Country's Share of World Pop  World Population  \
# 13          65415995                          2.63        4079480606
# ...

# %%
# Trazendo uma amostra aleatória.
brasil_population.sample()
# Out:
#    Year  Population  Yearly % Change  Yearly Change  Migrants (net)  \
# 6  2010   195713635             1.01        1917306               0
#
#    Median Age  Fertility Rate  Density (P/Km²)  Urban Pop %  Urban Population  \
# 6        29.2            1.86               23         84.8         165969018
#
#    Country's Share of World Pop  World Population  Brazil Global Rank
# 6                          2.81        6956823603                   5

# %%
# Colunas e seus nomes
brasil_population.columns
# Out:
# Index(['Year', 'Population', 'Yearly % Change', 'Yearly Change',
#        'Migrants (net)', 'Median Age', 'Fertility Rate', 'Density (P/Km²)',
#        'Urban Pop %', 'Urban Population', 'Country's Share of World Pop',
#        'World Population', 'Brazil Global Rank'],
#       dtype='object')

# %%
brasil_population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Year                          18 non-null     int64
#  1   Population                    18 non-null     int64
#  2   Yearly % Change               18 non-null     float64
#  3   Yearly Change                 18 non-null     int64
#  4   Migrants (net)                18 non-null     int64
#  5   Median Age                    18 non-null     float64
#  6   Fertility Rate                18 non-null     float64
#  7   Density (P/Km²)               18 non-null     int64
#  8   Urban Pop %                   18 non-null     float64
#  9   Urban Population              18 non-null     int64
#  10  Country's Share of World Pop  18 non-null     float64
#  11  World Population              18 non-null     int64
# ...

# %%
incendios_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6454 non-null   int64
#  1   state   6454 non-null   object
#  2   month   6454 non-null   object
#  3   number  6454 non-null   float64
#  4   date    6454 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 252.2+ KB
